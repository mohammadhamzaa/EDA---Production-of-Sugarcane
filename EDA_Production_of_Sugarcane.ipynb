# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("List of Countries by Sugarcane Production.csv")

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production (Tons)  \
# 0             0     Brazil  South America       768.678.382
# 1             1      India           Asia       348.448.000
# 2             2      China           Asia       123.059.739
# 3             3   Thailand           Asia        87.468.496
# 4             4   Pakistan           Asia        65.450.704
# ..          ...        ...            ...               ...
# 98           98    Lebanon           Asia                97
# 99           99   Djibouti         Africa                53
# 100         100  Singapore           Asia                50
# 101         101      Samoa        Oceania                12
# 102         102      Syria           Asia                 1
#
#     Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3.668,531        10.226.205             75.167,5
# 1                       260721         4.950.000             70.393,5
# ...

# %%
df.shape
# Out:
# (103, 7)

# %%
df.head(10)
# Out:
#    Unnamed: 0                   Country      Continent Production (Tons)  \
# 0           0                    Brazil  South America       768.678.382
# 1           1                     India           Asia       348.448.000
# 2           2                     China           Asia       123.059.739
# 3           3                  Thailand           Asia        87.468.496
# 4           4                  Pakistan           Asia        65.450.704
# 5           5                    Mexico  North America        56.446.821
# 6           6                  Colombia  South America        36.951.213
# 7           7                 Australia        Oceania        34.403.004
# 8           8                 Guatemala  North America        33.533.403
# 9           9  United States of America  North America        29.926.210
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %% [markdown]
# # **DATA** **CLEANING**

# %%
df["Production (Tons)"] = df["Production (Tons)"].str.replace(".","")
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].str.replace(".","").str.replace(",",".")
df["Acreage (Hectare)"] = df["Acreage (Hectare)"].str.replace(".","")
df["Yield (Kg / Hectare)"]= df["Yield (Kg / Hectare)"].str.replace(".","").str.replace(",",".")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
df[df["Acreage (Hectare)"].isnull()]
# Out:
#     Unnamed: 0   Country Continent Production (Tons)  \
# 99          99  Djibouti    Africa                53
#
#    Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 99                         51               NaN                  NaN

# %%
df=df.dropna().reset_index()

# %%
df.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production (Tons)  \
# 0      0           0    Brazil  South America         768678382
# 1      1           1     India           Asia         348448000
# 2      2           2     China           Asia         123059739
# 3      3           3  Thailand           Asia          87468496
# 4      4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
df.drop(["index" , "Unnamed: 0"],axis=1,inplace=True)

# %%
df.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     102 non-null    object
#  1   Continent                   102 non-null    object
#  2   Production (Tons)           102 non-null    object
#  3   Production per Person (Kg)  102 non-null    object
#  4   Acreage (Hectare)           102 non-null    object
#  5   Yield (Kg / Hectare)        102 non-null    object
# dtypes: object(6)
# memory usage: 4.9+ KB

# %%
df["Production (Tons)"] = df["Production (Tons)"].astype(float)
df["Acreage (Hectare)"] = df["Acreage (Hectare)"].astype(float)
df["Yield (Kg / Hectare)"] = df["Yield (Kg / Hectare)"].astype(float)
df["Production per Person (Kg)"] = df["Production per Person (Kg)"].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Country                     102 non-null    object
#  1   Continent                   102 non-null    object
#  2   Production (Tons)           102 non-null    float64
#  3   Production per Person (Kg)  102 non-null    float64
#  4   Acreage (Hectare)           102 non-null    float64
#  5   Yield (Kg / Hectare)        102 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 4.9+ KB

# %%
df.nunique()
# Out:
# Country                       102
# Continent                       6
# Production (Tons)             102
# Production per Person (Kg)    101
# Acreage (Hectare)             101
# Yield (Kg / Hectare)          102
# dtype: int64

# %% [markdown]
# # **UNIVARIATE** **ANALYSIS**

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %% [markdown]
# ### **How many countries produce sugarcane from each continent?**

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df["Continent"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ### **Distribution of the columns**

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
sns.distplot(df["Production (Tons)"])
plt.subplot(2,2,2)
sns.distplot(df["Production per Person (Kg)"])
plt.subplot(2,2,3)
sns.distplot(df["Acreage (Hectare)"])
plt.subplot(2,2,4)
sns.distplot(df["Yield (Kg / Hectare)"])
# Out:
# <ipython-input-24-5ec0737ff775>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production (Tons)"])
# <ipython-input-24-5ec0737ff775>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production per Person (Kg)"])
# ...

# %% [markdown]
# ### **Checking** **outliers**

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(df["Production (Tons)"])
plt.subplot(2,2,2)
sns.boxplot(df["Production per Person (Kg)"])
plt.subplot(2,2,3)
sns.boxplot(df["Acreage (Hectare)"])
plt.subplot(2,2,4)
sns.boxplot(df["Yield (Kg / Hectare)"])
# Out:
# <Axes: ylabel='Yield (Kg / Hectare)'>

# %%
df.describe()
# Out:
#        Production (Tons)  Production per Person (Kg)  Acreage (Hectare)  \
# count       1.020000e+02                  102.000000       1.020000e+02
# mean        1.850372e+07               112952.435755       2.498981e+05
# std         8.419149e+07               176651.341929       1.137003e+06
# min         1.000000e+00                    0.000000       0.000000e+00
# 25%         6.251875e+04                 3671.910000       1.104000e+03
# 50%         1.440044e+06                25572.500000       1.655800e+04
# 75%         6.426824e+06               146384.750000       8.047400e+04
# max         7.686784e+08               951087.000000       1.022620e+07
#
#        Yield (Kg / Hectare)
# count            102.000000
# mean           52628.078431
# std            30504.676683
# min               10.000000
# 25%            29072.025000
# 50%            54108.950000
# 75%            73282.700000
# max           129049.300000

# %% [markdown]
# ## **Bivariate Analysis**

# %%
df.head(7)
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
# 5    Mexico  North America         56446821.0                  452524.000
# 6  Colombia  South America         36951213.0                  740075.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0
# 5           781054.0                7227.0
# 6           416626.0               88691.5

# %% [markdown]
# ### **Which country produces maximum sugarcane?**

# %%
df_new = df[["Country" , "Production (Tons)"]].set_index("Country")

# %%
df_new.head()
# Out:
#           Production (Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0

# %%
df_new["Production(Tons)_percent"]= df_new["Production (Tons)"]*100/df_new["Production (Tons)"].sum()

# %%
df_new
# Out:
#            Production (Tons)  Production(Tons)_percent
# Country
# Brazil           768678382.0              4.072729e+01
# India            348448000.0              1.846200e+01
# China            123059739.0              6.520138e+00
# Thailand          87468496.0              4.634389e+00
# Pakistan          65450704.0              3.467809e+00
# ...                      ...                       ...
# Spain                  394.0              2.087551e-05
# Lebanon                 97.0              5.139401e-06
# Singapore               50.0              2.649176e-06
# Samoa                   12.0              6.358022e-07
# Syria                    1.0              5.298352e-08
#
# [102 rows x 2 columns]

# %%
df_new["Production(Tons)_percent"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df[["Country","Production (Tons)"]].set_index("Country").head(20).plot(kind = "bar")
# Out:
# <Axes: xlabel='Country'>

# %%
p = sns.barplot(data = df.head(15),  x= "Country", y = "Production (Tons)")
p.set_xticklabels(p.get_xticklabels(),rotation =75)
plt.show()
# Out:
# <ipython-input-33-6310d5ecd698>:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   p.set_xticklabels(p.get_xticklabels(),rotation =75)

# %% [markdown]
# **The country Brazil produces maximum sugarcane out of all countries**

# %% [markdown]
# ### **Which country has highest yield per hectare**

# %%
df_ah = df.sort_values("Yield (Kg / Hectare)", ascending = False).head(20)
p = sns.barplot(data = df_ah,  x= "Country", y = "Yield (Kg / Hectare)")
p.set_xticklabels(p.get_xticklabels(),rotation =75)
plt.show()
# Out:
# <ipython-input-34-63e3e56e9346>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   p.set_xticklabels(p.get_xticklabels(),rotation =75)

# %% [markdown]
# ### **Which country has highest land?**

# %%
df_ac = df.sort_values("Acreage (Hectare)", ascending = False).head(20)
p = sns.barplot(data = df_ac,  x= "Country", y = "Acreage (Hectare)")
p.set_xticklabels(p.get_xticklabels(),rotation =75)
plt.show()
# Out:
# <ipython-input-35-1d0ef32e8ac0>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   p.set_xticklabels(p.get_xticklabels(),rotation =75)

# %% [markdown]
# ### **Which country has highest production per person (kg) ?**

# %%
df_ypp = df.sort_values("Production per Person (Kg)", ascending = False).head(20)
ax = sns.barplot(data = df_ypp ,  x= "Country", y = "Production per Person (Kg)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =75)
plt.show()
# Out:
# <ipython-input-36-3e2c157bf6ad>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =75)

# %%
df.head()
# Out:
#     Country      Continent  Production (Tons)  Production per Person (Kg)  \
# 0    Brazil  South America        768678382.0                    3668.531
# 1     India           Asia        348448000.0                  260721.000
# 2     China           Asia        123059739.0                   88287.000
# 3  Thailand           Asia         87468496.0                    1264.303
# 4  Pakistan           Asia         65450704.0                  324219.000
#
#    Acreage (Hectare)  Yield (Kg / Hectare)
# 0         10226205.0               75167.5
# 1          4950000.0               70393.5
# 2          1675215.0               73459.1
# 3          1336575.0               65442.2
# 4          1130820.0               57879.0

# %% [markdown]
# ### **finding Correlation**

# %%
df_num = df[["Production (Tons)","Production per Person (Kg)","Acreage (Hectare)","Yield (Kg / Hectare)"]]

# %%
df_num.corr()
# Out:
#                             Production (Tons)  Production per Person (Kg)  \
# Production (Tons)                    1.000000                    0.015000
# Production per Person (Kg)           0.015000                    1.000000
# Acreage (Hectare)                    0.997550                    0.012557
# Yield (Kg / Hectare)                 0.132812                    0.017999
#
#                             Acreage (Hectare)  Yield (Kg / Hectare)
# Production (Tons)                    0.997550              0.132812
# Production per Person (Kg)           0.012557              0.017999
# Acreage (Hectare)                    1.000000              0.113433
# Yield (Kg / Hectare)                 0.113433              1.000000

# %%
sns.heatmap(df_num.corr(), annot =True, cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# ### **Do countries with highest land produce more sugarcane?**

# %%
sns.scatterplot(data = df,x ="Acreage (Hectare)", y= "Production (Tons)",hue = "Continent" )
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production (Tons)'>

# %% [markdown]
# ### **Analysis for Continent**

# %%
df["Continent"].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df_continent = df.groupby("Continent").sum()

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production (Tons)  Production per Person (Kg)  \
# Continent
# Africa                89681472.0                 2332636.293
# Asia                 721930425.0                 1857769.303
# Europe                    5823.0                     536.000
# North America        173995947.0                 3796081.508
# Oceania               36177574.0                   28593.605
# South America        865588126.0                 3505531.738
#
# ...

# %% [markdown]
# ### **Which continent produces maximum sugarcane?**

# %%
df_continent["Production (Tons)"].sort_values(ascending =  False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df_continent["Acreage (Hectare)"].sort_values(ascending =  False).plot(kind = "bar")
# Out:
# <Axes: xlabel='Continent'>

# %%
df_continent["number_of_countries"] = df.groupby("Continent").count()["Country"]

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production (Tons)  Production per Person (Kg)  \
# Continent
# Africa                89681472.0                 2332636.293
# Asia                 721930425.0                 1857769.303
# Europe                    5823.0                     536.000
# North America        173995947.0                 3796081.508
# Oceania               36177574.0                   28593.605
# South America        865588126.0                 3505531.738
#
# ...

# %% [markdown]
# ### **Do number of countries in a Continent effects production of sugarcane?**

# %%
continent_names = df_continent.index.to_list()
sns.lineplot(data = df_continent,x = "number_of_countries", y= "Production (Tons)" )
plt.xticks(df_continent["number_of_countries"], continent_names, rotation =90)
plt.show()

# %% [markdown]
# ### **Correlation for continent**

# %%
df_continent_corr = df_continent[["Production (Tons)","Production per Person (Kg)","Acreage (Hectare)","Yield (Kg / Hectare)" ,
                                 "number_of_countries"]]

# %%
df_continent_corr.corr()
# Out:
#                             Production (Tons)  Production per Person (Kg)  \
# Production (Tons)                    1.000000                    0.522211
# Production per Person (Kg)           0.522211                    1.000000
# Acreage (Hectare)                    0.994897                    0.463215
# Yield (Kg / Hectare)                 0.091201                    0.542961
# number_of_countries                  0.109244                    0.540086
#
#                             Acreage (Hectare)  Yield (Kg / Hectare)  \
# Production (Tons)                    0.994897              0.091201
# Production per Person (Kg)           0.463215              0.542961
# Acreage (Hectare)                    1.000000              0.111166
# Yield (Kg / Hectare)                 0.111166              1.000000
# number_of_countries                  0.132817              0.989712
#
#                             number_of_countries
# Production (Tons)                      0.109244
# ...

# %% [markdown]
# ### **Production distribution by continent**

# %%
plt.figure(figsize=(5,5))
df_continent["Production (Tons)"].plot(kind = "pie", autopct = "%.2f%%")
plt.title('Production Distribution by Continent')
plt.show()

# %% [markdown]
# ### **Do continent with highest land produces more sugarcane?**

# %%
sns.lineplot(data = df_continent,x = "Acreage (Hectare)", y= "Production (Tons)" )
# Out:
# <Axes: xlabel='Acreage (Hectare)', ylabel='Production (Tons)'>
